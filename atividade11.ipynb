# %%
# !pip install django
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 17.1 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/meuprojeto/
# Out:
# /content/drive/MyDrive/meuprojeto

# %%
# !ls
# Out:
# db.sqlite3  main  manage.py  meuprojeto

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://f0r63vgquyt-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
ALOWED_HOST = ['colab.research.google.com']

# %%
# !python manage.py runserver
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified some issues:
#
# WARNINGS:
# main.ProjetoDjango.data: (fields.W161) Fixed default value provided.
# 	HINT: It seems you set a fixed date / time / datetime value as default for this field. This may not be what you want. If you want to have the current date as default, use `django.utils.timezone.now`
#
# System check identified 1 issue (0 silenced).
# December 13, 2023 - 15:06:45
# Django version 5.0, using settings 'meuprojeto.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.

# %%
###repositorio do github###
# --> https://github.com/fabio432/pasta
