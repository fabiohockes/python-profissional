# %%
# !pip install django

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/meuprojeto/
# Out:
# /content/drive/MyDrive/meuprojeto

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://mji2cdefgdp-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
ALOWED_HOST = ['colab.research.google.com']

# %%
# !python manage.py runcserver 8000

# %%
# repositorio github
""" https://github.com/fa095/EstudoGit  """
# Out:
# 'https://github.com/fa095/EstudoGi'
