# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
def extration(self):
  #Carrega o documento HTML  (pode ser um arquivo ou uma string)
  url = 'https://www.w3schools.io/file/yaml-introduction'
  response = requests.get(url)

# %%
soup = BeautifulSoup('response.text, <html lang=en-us>')

# %%
from ast import Attribute
#localizar um elemento HTML por sua tag e atributo
elements = soup.find('tag', {'Attribute': '<title> + </title>'})
elements = soup.find('tag', {'Attribute': '<meta chaset= utf-8> + </meta chaset= utf-8>'})

#extrai o texto do documentos
text = 'elements.text'

# %%
#localizar todos os elementos que correspondem a um seletor e os retorna em uma lista
elements = soup.find_all('<body> += </body>', {'<span> += </span>': '+1'})
print('elements')

# %%
#retorna o documentos HTML ou XML formatado de forma mais legivel, com indetacao
html_formats = soup.prettify
print('html_formats')
